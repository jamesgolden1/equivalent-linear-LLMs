# %% [markdown]
# <a href="https://colab.research.google.com/github/jamesgolden1/llms-are-llms/blob/main/notebooks/llama_3/llama_3_1_8B_locally_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install "huggingface_hub[hf_transfer]"

# %%
import os
from google.colab import userdata

os.environ["HF_HUB_ENABLE_HF_TRANSFER"]='1'
os.environ["HF_TOKEN"] = userdata.get('HF_TOKEN')
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# %%
os.environ['GITHUB_TOKEN']=userdata.get('GITHUB_TOKEN')

# %%
# !git clone https://jamesgolden1:$GITHUB_TOKEN@github.com/jamesgolden1/llms-are-llms.git
# Out:
# Cloning into 'llms-are-llms'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (81/81), done.
# remote: Total 137 (delta 68), reused 88 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (137/137), 3.33 MiB | 29.90 MiB/s, done.
# Resolving deltas: 100% (68/68), done.

# %%
cd llms-are-llms
# Out:
# /content/llms-are-llms

# %%
from src.JacobianAnalyzer import *

# %%
from src.JacobianAnalyzer import JacobianAnalyzer as JacobianAnalyzer

# %%
# from models.llama_3.llama_3_forward import model_forward
# setattr(JacobianAnalyzer, 'model_forward', model_forward)

# %%
#@title Run Jacobian Analysis
# %%time
# %%writefile run_llama.py
import os
import gc
import torch
import argparse

run_all=True

# Initialize the analyzer
analyzer = JacobianAnalyzer(model_name="meta-llama/Llama-3.2-3B-Instruct")

# text = 'The Golden'
text = 'The bridge out of Marin is the'
max_new_tokens=1
temperature=1e-6

# Generate output
analyzer.generate(text, max_new_tokens, temperature);

# # # Compute Jacobian
analyzer.compute_jacobian()
analyzer.compute_jacobian_nonlinear()
analyzer.plot_jacobian_comparison(text,filename_png="fig3")

analyzer.compute_jacobian_row_col_norm(n_components=8)#, svs=1)
analyzer.plot_singular_values(mode="row_col_vectors",filename_png="fig4_col")

analyzer.compute_jacobian_svd(n_components=24, svs=1)
analyzer.plot_singular_values(filename_png="fig4_svd")

analyzer.plot_jacobian_image(filename_png="fig2")

if run_all:
    layerlist=list(range(1,23,3))
    layerlist.extend([24,25,26,27])
    analyzer.compute_jacobian_layers_svd(layerlist=layerlist,n_components=64,svs=8)#,filename="fig5_svd_layers_llama_3_2")
    analyzer.plot_singular_values(mode='singular_vectors_layers',key='layer',filename_png="fig5_svd_layers")

    analyzer.compute_jacobian_layers_svd(layerlist=layerlist,n_components=24,svs=8,key='mlp')#,filename="fig5_svd_layers_llama_3_2_mlp")
    analyzer.plot_singular_values(mode='singular_vectors_layers',key='mlp',filename_png="fig5_svd_mlp")

    analyzer.compute_jacobian_layers_svd(layerlist=layerlist,n_components=24,svs=8,key='attn')#,filename="fig5_svd_layers_llama_3_2_attn")
    analyzer.plot_singular_values(mode='singular_vectors_layers',key='attn',filename_png="fig5_svd_attn")

    analyzer.plot_path(filename_png="fig6_path")
    analyzer.plot_dimensionality(filename_png="fig6_dimensionality")

    analyzer.compute_jacobian_layers_svd(layerlist=layerlist,layer_mode='layerwise',n_components=24,svs=8)#,filename="fig5_svd_layers_llama_3_2")
    analyzer.plot_singular_values(mode='singular_vectors_layers_layerwise',key='layer',filename_png="fig5_svd_layers_layerwise")

    analyzer.compute_jacobian_layers_svd(layerlist=layerlist,layer_mode='layerwise',n_components=24,svs=8,key='mlp')#,filename="fig5_svd_layers_llama_3_2_mlp")
    analyzer.plot_singular_values(mode='singular_vectors_layers_layerwise',key='mlp',filename_png="fig5_svd_mlp_layerwise")

    analyzer.compute_jacobian_layers_svd(layerlist=layerlist,layer_mode='layerwise',n_components=24,svs=8,key='attn')#,filename="fig5_svd_layers_llama_3_2_attn")
    analyzer.plot_singular_values(mode='singular_vectors_layers_layerwise',key='attn',filename_png="fig5_svd_attn_layerwise")

    analyzer.plot_dimensionality(layerwise=True,filename_png="fig6_dimensionality_layerwise")

# # if __name__ == "__main__":
# #     main()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# model_forward_error: tensor([0., 0., 0.,  ..., 0., 0., 0.], device='cuda:0', dtype=torch.bfloat16,
#        grad_fn=<SubBackward0>)
# model_forward_error allclose: True
# detached Jacobian error: tensor([ 0.0000,  0.0034,  0.0625,  ...,  0.0078, -0.0215,  0.0078],
#        device='cuda:0', dtype=torch.bfloat16, grad_fn=<SubBackward0>)
# detached Jacobian all close: False
# For lowest Jacobian error, run at float32 precision on an A100. You can also run float32 on CPU on an L4 but it is slow.
# Computing col norms for token position 0
# Computing col norms for token position 1
# Computing col norms for token position 2
# Computing col norms for token position 3
# Computing col norms for token position 4
# Computing col norms for token position 5
# Computing col norms for token position 6
# Computing col norms for token position 7
# Mode: row_col_vectors
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 21482 (\N{CJK UNIFIED IDEOGRAPH-53EA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 21482 (\N{CJK UNIFIED IDEOGRAPH-53EA}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# Computing SVD for token position 0
# Computing SVD for token position 1
# Computing SVD for token position 2
# Computing SVD for token position 3
# Computing SVD for token position 4
# Computing SVD for token position 5
# Computing SVD for token position 6
# Computing SVD for token position 7
# Token 0, SV 0:  most best one I " D only
# Token 0, SV 0: [' now', '只', ' few', ' 只', ' !', ' range', '.Range', 'OUR']
#
# Token 1, SV 0:  most one best I B only first
# Token 1, SV 0: ['The', 'the', 'St', 'THE', '.The', '"The', '_the', 'One']
#
# Token 2, SV 0:  most one " I B only best
# Token 2, SV 0: [' bridge', ' Bridge', ' bridges', ' Brid', ' Bridges', '_bridge', '桥', ' brid']
#
# Token 3, SV 0:  most one best Marin only Mar "
# Token 3, SV 0: [' out', ' OUT', 'Out', '-out', '.out', '\tout', ' exit', '[out']
#
# Token 4, SV 0:  most Marin one best only Mar last
# Token 4, SV 0: [' off', ' into', ' from', ' exit', ' service', ' Of', ' entrance', 'OutOf']
#
# Token 5, SV 0: Marin most  Bay best only one Mar
# Token 5, SV 0: [' Marin', '�', ' marin', ' Marie', ' Maine', ' Arc', ' Pine', ' Peninsula']
#
# Token 6, SV 0:  most one best first same last B
# Token 6, SV 0: [' is', ' was', ' are', '\tis', 'is', 'was', ' IS', ' Was']
#
# Token 7, SV 0: most  longest first one final last best
# Token 7, SV 0: [' the', ' THE', 'The', '-the', '_the', ' his', '"The', '(the']
#
# Mode: singular_vectors
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# Layer 1
# Computing SVD for token position 0
# Token 0, SV 0: illumin ulp train � ing . or Morph
# Token 0, SV 1: abs as in at and  or for
# Token 0, SV 2: itage atorio vos phants Ön télé egrity 顿
# Token 0, SV 3: the a Pricing both quite his neither an
# Token 0, SV 4:  / - _ ( , de
# Token 0, SV 5: ye Ram response Duy polym Kun hall readers
# Token 0, SV 6: Bond idis thoát bond Anglo brink Bond tas
# Token 0, SV 7: ** ...) foreign hand Y Starter uffers '
# Layer 4
# Computing SVD for token position 0
# Token 0, SV 0: alta onis umo ̂ eric 案 conserve Manip
# Token 0, SV 1: Bach Sac Katz Same SAME ZN 门 isque
# Token 0, SV 2: arium erne abouts olan 任 steam axon _pairs
# Token 0, SV 3: udes aines means herb Means Pow assing Means
# Token 0, SV 4: Spar spar reins jas yours asu Jas Ras
# Token 0, SV 5: olina color bucket dir detail irection pair family
# Token 0, SV 6: main context agh Main Ear olas 处 utta
# Token 0, SV 7: oup assist bour pei ghi edin Schmidt olini
# Layer 7
# Computing SVD for token position 0
# Token 0, SV 0: legen dir yte 流 lessly pseudo 具 uniform
# Token 0, SV 1: Advoc atsu orges omers rock yles erb iley
# Token 0, SV 2: ideas orean recommendations tant sole än .withOpacity اده
# Token 0, SV 3: Class Echo alc lass ucch thing 丝 fine
# Token 0, SV 4: Rosenstein exponentially QL initialised ीएम exit exhausted initialise
# Token 0, SV 5: recent Claudia ole ysl motor ablo Wings oro
# Token 0, SV 6: ippo virtual itz Virtual tach pick � virtual
# Token 0, SV 7: pitch switch べ projects routine SPD 密 aling
# Layer 10
# Computing SVD for token position 0
# Token 0, SV 0: Standing Auditor unal Ses Synd Pes frontal İs
# Token 0, SV 1: authorised ones atel getClient تی dese Pets minimise
# Token 0, SV 2: czy bridge Blvd Shotgun än 所 Bridge jus
# Token 0, SV 3: 田 ql {{ backing zw solitary � reprodu
# Token 0, SV 4: aina Reyn s itter means Gazette Convention advertiser
# Token 0, SV 5: alus disin furniture vat cud wi edian �
# Token 0, SV 6: obile Nej heel emory lift orc ovie Nobel
# Token 0, SV 7: mom Bias JNI thru mimo Mom правда Driver
# Layer 13
# Computing SVD for token position 0
# Token 0, SV 0: plier legen flop anity accordingly manipulated romise nou
# Token 0, SV 1: 另 Cos mute way amar ones -svg oftware
# Token 0, SV 2: asar azel TTY antro nos Eag vergence verted
# Token 0, SV 3: McGu Bakan nearby icone nowhere Via agal uario
# Token 0, SV 4: umbing quito zac lids olest shrinking Asked usual
# Token 0, SV 5: Equivalent Mouth anth mouth iper adero Foot Equivalent
# Token 0, SV 6: ounder cares arf pto toile jure contested cared
# Token 0, SV 7: 結 thes 導 Carr ohan tep roofs pek
# Layer 16
# Computing SVD for token position 0
# Token 0, SV 0: correct absolute appropriate sing pired sud что lowest
# Token 0, SV 1: Highway ones highway continuation way green authorised busiest
# Token 0, SV 2: null ours either outil from 越 beyond ally
# Token 0, SV 3: 断 bridges tol freeway bridge .shtml arterial congest
# Token 0, SV 4: itty inevitable standard ètres ater GRAM atre oline
# Token 0, SV 5: California cres sanitizer laid bay lein grac California
# Token 0, SV 6: Bay ange bay Bay Slow sne fur Yuri
# Token 0, SV 7: Ire Downing 地下 Kern bridge elia Aging Berm
# Layer 19
# Computing SVD for token position 0
# Token 0, SV 0: only lest correct perfect less best combined wont
# Token 0, SV 1: bridge busiest Highway highway ones bridges main Bridge
# Token 0, SV 2: colored bean thru (es harbor everyone ouver nothing
# Token 0, SV 3: Berkeley Oakland Fairfield California freeway � Stanford emento
# Token 0, SV 4: Bay Oakland Berkeley California Bay bay Tokyo Sacramento
# Token 0, SV 5: -sur most ترین мя abay auss agu ascar
# Token 0, SV 6: ones ă blade fur longest Vale annon Hack
# Token 0, SV 7: Stanford owa ือน 津 affirmative ochrome undertaking idan
# Layer 22
# Computing SVD for token position 0
# Token 0, SV 0: most only lest very best same easiest highest
# Token 0, SV 1: bridge toll Highway bridges busiest highway Bridge tol
# Token 0, SV 2: Bay Marin Bay Berkeley Oakland California San California
# Token 0, SV 3: Berkeley Silicon Sacramento Oakland \Traits fastest ablish uire
# Token 0, SV 4: beach beaches Bay coastline Beach bay coastal seaside
# Token 0, SV 5: Marlins Florian roman roman Croat Roman .pop Romanian
# Token 0, SV 6: Mountain valley mountain Mountain Valley Tahoe Avalanche Sacramento
# Token 0, SV 7: Newark Bridge bridge Bridge Brooklyn brid Greenwich Brid
# Layer 24
# Computing SVD for token position 0
# Token 0, SV 0: most best lest highest least strongest worst only
# Token 0, SV 1: bridge toll busiest bridges tol Bridge Highway connector
# Token 0, SV 2: Marin marin California Oakland Bay Bay Berkeley California
# Token 0, SV 3: beach Marine marine Marines marine marin Marina mar
# Token 0, SV 4: San Berkeley Silicon San Bay Sacramento san bay
# Token 0, SV 5: mar Mar Mar Marion marin MAR mar Marines
# Token 0, SV 6: Mountain valley mountain Valley Mountain Tahoe Yosemite Lake
# Token 0, SV 7: Newark Auckland Bayesian Bridge bridge Bridge Greenwich 東京
# Layer 25
# Computing SVD for token position 0
# Token 0, SV 0: most least best largest only highest smallest lest
# Token 0, SV 1: bridge toll busiest Highway bridges tol Bridge connector
# Token 0, SV 2: Marin marin California Bay Bay Oakland California Feinstein
# Token 0, SV 3: Marines Marin bod ทะ marin programme beach Marina
# Token 0, SV 4: San Berkeley Silicon San san Sacramento SF Oakland
# Token 0, SV 5: Marion marin mar Mar MAR Marines Marlins Mar
# Token 0, SV 6: valley Valley Mountain mountain Mountain Yosemite Lake Walnut
# Token 0, SV 7: Newark Auckland Greenwich Programme erection oklyn 東京 retrofit
# Layer 26
# Computing SVD for token position 0
# Token 0, SV 0: most least best same very only final first
# Token 0, SV 1: bridge toll busiest scenic longest oldest Highway Bridge
# Token 0, SV 2: Marin marin Bay Bay California Oakland MAR Feinstein
# Token 0, SV 3: bod Marin Marines marin programme ทะ camp deserted
# Token 0, SV 4: San san Berkeley Silicon San fastest bay SF
# Token 0, SV 5: Marion marin MAR Mar Marino Marlins mar Mar
# Token 0, SV 6: valley Valley Mountain Yosemite mountain Lake Mountain Tahoe
# Token 0, SV 7: Newark Programme Auckland retrofit erection Manhattan Greenwich insufficient
# Layer 27
# Computing SVD for token position 0
# Token 0, SV 0: only most last final first next same new
# Token 0, SV 1: toll bridge scenic entrance longest main busiest cause
# Token 0, SV 2: Marin marin arin ugin Bay MAR California Feinstein
# Token 0, SV 3: programme Marin camp programmes bod colour behaviour deserted
# Token 0, SV 4: marin Marin Marion kin phin Rin sincer fastest
# Token 0, SV 5: San SF Berkeley Bay san bay San UC
# Token 0, SV 6: valley Valley Mountain Sierra Yosemite mountain Tahoe Silicon
# Token 0, SV 7: Newark Auckland Programme movable insufficient erection wat diarr
# Mode: singular_vectors_layers
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 26696 (\N{CJK UNIFIED IDEOGRAPH-6848}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 27969 (\N{CJK UNIFIED IDEOGRAPH-6D41}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 20855 (\N{CJK UNIFIED IDEOGRAPH-5177}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 26696 (\N{CJK UNIFIED IDEOGRAPH-6848}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 27969 (\N{CJK UNIFIED IDEOGRAPH-6D41}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 20855 (\N{CJK UNIFIED IDEOGRAPH-5177}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# Layer 1
# Computing SVD for token position 0
# Token 0, SV 0: , . os iro ides i ar ce
# Token 0, SV 1: ,   . ( - and in
# Token 0, SV 2: prosec endo uni ​​ rosso 展 cone å
# Token 0, SV 3: active res finish blur いる ataka active Rah
# Token 0, SV 4: uko Beispiel odel traction ske idding Disc sàng
# Token 0, SV 5: stru INGS aug tiler autoload hana ardu orda
# Token 0, SV 6: - .  a B T P
# Token 0, SV 7: GIN mpl celik организа oren BOR gons �
# Layer 4
# Computing SVD for token position 0
# Token 0, SV 0: skeleton opo enberg otos placeholders PIP � Moran
# Token 0, SV 1: enn 莫 ugen Fleming reg BT bomb something
# Token 0, SV 2: tro traff launder Trojan trak quam anzi esser
# Token 0, SV 3: ATM ificent hang aight pur antar reflecting reflection
# Token 0, SV 4: Bin tw awi � ei Tw ROUND Sharp
# Token 0, SV 5: licable loads excuse reach merc itecture shares aping
# Token 0, SV 6: jure ael ovol aro rear pun _pair malar
# Token 0, SV 7: needs erman .rec Clarke ulo oub áp aut
# Layer 7
# Computing SVD for token position 0
# Token 0, SV 0: olar &action alternatively arks olved -ed sleeves asley
# Token 0, SV 1: itters umu ôn avity SUMMARY abh tab nte
# Token 0, SV 2: uck Holiday ixo Holiday Grade ettes oggle Progress
# Token 0, SV 3: ारक FA annon анта ango amation opyright imos
# Token 0, SV 4: bro ehr Import ou imported gras atories ordan
# Token 0, SV 5: avs ansas skills Kum allax Ober Lessons Koreans
# Token 0, SV 6: zel ạt derby aley oggler Eff Fake Across
# Token 0, SV 7: variants Shepard ilar ча marg frag sending ramento
# Layer 10
# Computing SVD for token position 0
# Token 0, SV 0: onda ogui jitter cleanliness locker arta conditioning oga
# Token 0, SV 1: ards commentators andbox IDDLE wicked EMA achers Marion
# Token 0, SV 2: tí fir luv pinch uj misc uably osy
# Token 0, SV 3: pret vid Trident rings emens Pret าย instrumental
# Token 0, SV 4: motifs oq mant porte oten Gry busy motif
# Token 0, SV 5: rend ty rende AIDS ka Underground critically touching
# Token 0, SV 6: regon Against against Lil Rice rice English aben
# Token 0, SV 7: etchup 言 onec zheimer pump alsa Пов slowing
# Layer 13
# Computing SVD for token position 0
# Token 0, SV 0: introductory intro emoc Butt รม Regents cí Eag
# Token 0, SV 1: yre sole heimer lav intention lus Vim Unlock
# Token 0, SV 2: Sage pres gain pretty infl manip maj ison
# Token 0, SV 3: sense reproductive sense jer Body ello ilmington rocket
# Token 0, SV 4: Ramirez inct 玄 lead Pascal dez erset ichel
# Token 0, SV 5: ikh ica ads ade ic odel ú constructs
# Token 0, SV 6: Wings ear romatic graduation Romance rot pac romance
# Token 0, SV 7: few airo spared amort Wax _sentence 衝 dri
# Layer 16
# Computing SVD for token position 0
# Token 0, SV 0: overall read Overall ̃ vib quoted uly trick
# Token 0, SV 1: Highway highways anding compress quer oni highway roads
# Token 0, SV 2: MP mp architecture architecture dol istar Civil vitamin
# Token 0, SV 3: straw region recreation ulous hack unky � ASAP
# Token 0, SV 4: Witness burning zie Witness umm posing Reform fare
# Token 0, SV 5: Transit cular avern rush uct ioned transit Μέ
# Token 0, SV 6: ago Tigers AGO Hist नल unda quality intelligent
# Token 0, SV 7: zf amas sens baked amat Gil caled वक
# Layer 19
# Computing SVD for token position 0
# Token 0, SV 0: quarters hood 阵 hone Hue Pul trif раж
# Token 0, SV 1: gate gate pass Gate bridge highway highways gates
# Token 0, SV 2: emento amba Oakland osis punct SON олю 415
# Token 0, SV 3: aul allo unidentified enne olmadı Wert Toll ِم
# Token 0, SV 4: elevator highways highway maf Highway freeway ued ifier
# Token 0, SV 5: orsk ophil Owl Chain chiefs Chain виж Chiefs
# Token 0, SV 6: pose owski ultimate lands Rebel inci aceut ergy
# Token 0, SV 7: Highway oko respectively 利 Tir 号 zac matched
# Layer 22
# Computing SVD for token position 0
# Token 0, SV 0: br Br pont br Pont span spans olia
# Token 0, SV 1: heart brig heart ouver Heart Heart amba annel
# Token 0, SV 2: Washington Farmer Hà overlap Ha Musk Ottawa Nik
# Token 0, SV 3: coast Terr 沿 docks strand wildfires dock Coal
# Token 0, SV 4: hang zone unes Mile Zone تب Panel ết
# Token 0, SV 5: incy urse enriched ductor Hol arez izr icast
# Token 0, SV 6: mount bags mountain agendas AGEMENT -mount bar triangle
# Token 0, SV 7: guts Cash brush cash Reserve Cash lieu oppins
# Layer 24
# Computing SVD for token position 0
# Token 0, SV 0: driving driver drive drivers drove Driving vehicle -driving
# Token 0, SV 1: last Last last LAST Last mint -last hoops
# Token 0, SV 2: almond Gin rec din whisk emot ysis dib
# Token 0, SV 3: lein aptic agt allas aab ien innen lien
# Token 0, SV 4: Train Qu amac ambre Railroad manent train �
# Token 0, SV 5: isi Wie akah uela uya zig ike overlay
# Token 0, SV 6: � right Agency mil Right Agency right Stop
# Token 0, SV 7: inois ZO neys unos cus quet TargetException Mud
# Layer 25
# Computing SVD for token position 0
# Token 0, SV 0: span G f B Span c E F
# Token 0, SV 1: argar extrem D ercul circular eighth Circular าศ
# Token 0, SV 2: ocean beach Ocean sea Beach maritime beaches seaw
# Token 0, SV 3: sle hug ieber forge lookout terminal ible stealth
# Token 0, SV 4: span whe wh Span ight contr lean Span
# Token 0, SV 5: shore Shore Coast coast sailors Beach sea ocean
# Token 0, SV 6: s cr Derrick heraus determinant sea emann twice
# Token 0, SV 7: Starr central quil oyer -blood verr linger PCR
# Layer 26
# Computing SVD for token position 0
# Token 0, SV 0: same final state finally very br same Br
# Token 0, SV 1: site Oak Friendship Aug Rand pow tracks Legacy
# Token 0, SV 2: through through -through THROUGH Through thru através Through
# Token 0, SV 3: guard Als Duty vir Trail duty ตร trouble
# Token 0, SV 4: 's br br instr batteries -br linger \'
# Token 0, SV 5: damages stare ALAR semiconductor azing marsh atus agma
# Token 0, SV 6: firm omo absolute zed ward showroom Fried 敷
# Token 0, SV 7: uger amet urar oser instal obia ober ubs
# Layer 27
# Computing SVD for token position 0
# Token 0, SV 0: last new only V trans F on T
# Token 0, SV 1: I  St the r And and He
# Token 0, SV 2: beyond kernel Oakland pe equilibrium lever body type
# Token 0, SV 3: exper defective nect ehr distinctive onian ine disin
# Token 0, SV 4: not Not Not v olic not dw only
# Token 0, SV 5: I I -to in a L In spo
# Token 0, SV 6: bridge bridge oken Bridge AsString rid Bridge pit
# Token 0, SV 7: rein anim burn Br ickle Batch burns 937
# Mode: singular_vectors_layers
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 38453 (\N{CJK UNIFIED IDEOGRAPH-9635}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 38453 (\N{CJK UNIFIED IDEOGRAPH-9635}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# Layer 1
# Computing SVD for token position 0
# Token 0, SV 0:  , ( and in .  -
# Token 0, SV 1: , .  : - (  /
# Token 0, SV 2: 1  2 - 3 a B A
# Token 0, SV 3: 1 � Pare gebra 2 ah 4 umn
# Token 0, SV 4: ?") ?): ."). appare ystack Formats contre ?).
# Token 0, SV 5: impunity - z 1 f  in av
# Token 0, SV 6: olg � competit � overst knowledgeable Corp oin
# Token 0, SV 7: . , to of . in ( and
# Layer 4
# Computing SVD for token position 0
# Token 0, SV 0: Ahead ahead ahead omb Trou omm Ahead omi
# Token 0, SV 1: hindsight Shooter amation -between Carly rometer uds aps
# Token 0, SV 2: ért wen ech Past past 过去 amate 류
# Token 0, SV 3: lifetime lifetime -val des Edition spell clidean chalk
# Token 0, SV 4: stock � sembl Case � sami Nash ython
# Token 0, SV 5: aster Tome filter readability Personal év .filter Perform
# Token 0, SV 6: образ punk MAC orch qed äh buck MAC
# Token 0, SV 7: erv Zheng mesh entric mesh establishment aru ight
# Layer 7
# Computing SVD for token position 0
# Token 0, SV 0: Potato lamin Shelter verte Weed erty � .setup
# Token 0, SV 1: dual twin Dual Independence (ed Dual Segment azer
# Token 0, SV 2: ủng floats extrapol leftovers pic broker bab Delegate
# Token 0, SV 3: eba lege 杯 coun Pert MACHINE Seconds 機
# Token 0, SV 4: au anten Hanson distribution Cannes attended ender Masters
# Token 0, SV 5: keh eda Tess whose abeled abis nj abled
# Token 0, SV 6: duk apiro └ 阅 平 руд ur Lie
# Token 0, SV 7: pitch eman awai aset oses kip delayed 払
# Layer 10
# Computing SVD for token position 0
# Token 0, SV 0: afia departing .evaluate ля iled opia phem encountering
# Token 0, SV 1: segue dip dere mens Personal apesh Bloc mens
# Token 0, SV 2: uppet __). onte esan Wat ulton trưng ga
# Token 0, SV 3: either somewhere Comb comb everywhere quarter Pers 獲
# Token 0, SV 4: Sands Guess nation games ipers tradition often isin
# Token 0, SV 5: trash hack рен вал akat shall arty omp
# Token 0, SV 6: ickle rubber bucket inary repro bl blues assin
# Token 0, SV 7: 易 electrical बर sacr hem Emerald em �
# Layer 13
# Computing SVD for token position 0
# Token 0, SV 0: roma pride Pride umeric omo romantic Russo opoly
# Token 0, SV 1: oter Pon iner Bij Mend hộ 抗 ont
# Token 0, SV 2: primaries primary boro åde проп upt strike Renders
# Token 0, SV 3: Epoch Freed unrecognized deaths ucha afi Shadows ocl
# Token 0, SV 4: verse pac carry mites pac VERSE survival hor
# Token 0, SV 5: historic local downtown civic Historic cen Buff Terr
# Token 0, SV 6: ilos sudden hardcore caused ogl intentional demand necess
# Token 0, SV 7: roadside axe [++ oldt Added aten cr &M
# Layer 16
# Computing SVD for token position 0
# Token 0, SV 0: ibri above Above blink ород RIX Above asc
# Token 0, SV 1: Bay Bay bay bay stan mast major ushima
# Token 0, SV 2: alach Wichita Tulsa Swansea Arkansas .lua XL Memphis
# Token 0, SV 3: island sea seas islands 節 marine Islands marine
# Token 0, SV 4: Northwest NORTH ATL Pompe STM North Canadiens Gibraltar
# Token 0, SV 5: sea seaw coastal Sea Sea beach Ocean Maritime
# Token 0, SV 6: airst Sanctuary Mountain country iper Nil Canter ipo
# Token 0, SV 7: Montana Southampton Naples Cornwall Maui Hawaiian Lancaster Santa
# Layer 19
# Computing SVD for token position 0
# Token 0, SV 0: independently asil ator til 相 flat flat oute
# Token 0, SV 1: ones only basis Basis point reason Double Double
# Token 0, SV 2: atchet ,and ach bsd etin athers orough anut
# Token 0, SV 3: aring eka prayed arend Kaplan falta ars Marie
# Token 0, SV 4: cellul wal usable 779 pro inet perm YZ
# Token 0, SV 5: ingly pte indi ably Url azel GI Id
# Token 0, SV 6: estre dal ести шись likes otas orners .messaging
# Token 0, SV 7: GBT レー hardest terminator **, `, inke рич
# Layer 22
# Computing SVD for token position 0
# Token 0, SV 0: bridge bridge brid bridges brig Bridge Bridge BR
# Token 0, SV 1: San Bay San Oakland Bay bay SAN san
# Token 0, SV 2: bridge Bridge Bridge brid bridge Brid bridges brid
# Token 0, SV 3: Bridge bridge Bridge bridge Florida Miami Florida Miami
# Token 0, SV 4: Fresno Palo Stamford Stanford Google Sacramento Uzbek Cupertino
# Token 0, SV 5: mountain Orange Swiss Mountain Orange Los Mountain Santa
# Token 0, SV 6: ocean coastal seaw beach surf Ocean Coastal Sea
# Token 0, SV 7: Monterey Yosemite California Tahoe Santa Santa Fresno Colorado
# Layer 24
# Computing SVD for token position 0
# Token 0, SV 0: Mar mar Flavor Mar phins Marlins battery .Mar
# Token 0, SV 1: br BR -br Brave Br Brad brig br
# Token 0, SV 2: county เฟ Harvey pla County ple sheriff ,count
# Token 0, SV 3: honour neighbourhood Central Central programmes jewellery programme neighbour
# Token 0, SV 4: br Br br Br -br brake BR .br
# Token 0, SV 5: County county County county counties COUNTY Counties -count
# Token 0, SV 6: neighbours philosoph neighbourhood Erf qa Manifest programmes neighbour
# Token 0, SV 7: sailing sail sailed sailors sailor Sail ship city
# Layer 25
# Computing SVD for token position 0
# Token 0, SV 0: Marin Levin Rubin Marino GIN ASN Wein Devin
# Token 0, SV 1: […]   ... [... ... ,...  s  n
# Token 0, SV 2: Marin bridges arin brid INA Levin bridge Bray
# Token 0, SV 3: bridges Bridges brid Bridge bridge Bridge bridge _bridge
# Token 0, SV 4: Tasmania Vanderbilt immer Kendall keh plot classNames ToString
# Token 0, SV 5: Charge charge Out ctor lett amazon charge usan
# Token 0, SV 6: atak Sheffield Chester Canterbury Cumberland Cornwall Damien
# Token 0, SV 7: onto out Fairfax atio down 卓 -for Jenner
# Layer 26
# Computing SVD for token position 0
# Token 0, SV 0: रण vs scape dangerously african Clarence tica affect
# Token 0, SV 1: oping quelle Construction Marina Acts remar Construction impro
# Token 0, SV 2: Tom tom Tom TOM .tom tomato tom Tommy
# Token 0, SV 3: tol toll Millennium clamation ić 심 Toll adm
# Token 0, SV 4: Cam Lv cam mont cam Zag CM Gö
# Token 0, SV 5: Sha ern apo ere Jacqueline kin DMA erna
# Token 0, SV 6: Hol TC Hol bar cams .flat CAM Burl
# Token 0, SV 7: rought Engineers Ped Michael MIC uentes Kv Engineering
# Layer 27
# Computing SVD for token position 0
# Token 0, SV 0: Marin Din Gin _sin 'a Tin kin sin
# Token 0, SV 1: ... “ ... ...   ... .... --
# Token 0, SV 2: Marin Cin Kin din arin Hin Din cin
# Token 0, SV 3: […] <|end_of_text|> — [... "][" [...] []. ﻿
# Token 0, SV 4: [...] ... -- […] ": "): ..." …
# Token 0, SV 5: ... ... ..." … ... ... )... ...(
# Token 0, SV 6: & -- – ` -- & "-- `
# Token 0, SV 7: ‘ Cro Cro ‘ cro cro ’ honour
# Mode: singular_vectors_layers
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 2339 (\N{DEVANAGARI LETTER NNA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 2339 (\N{DEVANAGARI LETTER NNA}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# Layer 1
# Computing SVD for token position 0
# Token 0, SV 0: /or � ing . or illumin equ morph
# Token 0, SV 1: abs and as , in or  at
# Token 0, SV 2: itage atorio phants vos 顿 télé Ön egrity
# Token 0, SV 3: the a Pricing his quite both you an
# Token 0, SV 4:  - / , (  _ de
# Token 0, SV 5: ye Ram response polym readers Duy Kun crossover
# Token 0, SV 6: Bond thoát bond brink idis bonded Anglo tas
# Token 0, SV 7: ...) ** Starter Wolff foreign uffers Y chers
# Layer 4
# Computing SVD for token position 0
# Token 0, SV 0: stands correction unge arm accompanying application avigation ager
# Token 0, SV 1: Architect alto elev instein entin itecture architect elevation
# Token 0, SV 2: agne κλη prev hall adm trav Celebr prefab
# Token 0, SV 3: � overview conda raz crossing directions vicinity 向
# Token 0, SV 4: VRT embar cosy apt Compass igos heim crets
# Token 0, SV 5: fossils Ecuador cli ove cntl ุร faithful ocker
# Token 0, SV 6: elt Loud Carbon tab carbon esti lang oley
# Token 0, SV 7: Cable ayne aph PERSON cables CType chor  je
# Layer 7
# Computing SVD for token position 0
# Token 0, SV 0: antium imas Advice enal อง Preston spas zano
# Token 0, SV 1: dram Typ tees eting crime Pole � iere
# Token 0, SV 2: angle ห Leigh OCR UMENT suspects figured dön
# Token 0, SV 3: омер annes � Short Global sterol 律 global
# Token 0, SV 4: маз iphone Lump ount 격 vik cách cleaned
# Token 0, SV 5: dra programm mó pa erset draw gi Mour
# Token 0, SV 6: ateful � Moderate maint ordering chen onica cathedral
# Token 0, SV 7: elf aget div cheid owell imp itution Basket
# Layer 10
# Computing SVD for token position 0
# Token 0, SV 0: .python division repar 回 Mess mess pale 第
# Token 0, SV 1: bare riet .vo Bare slots odings recht 물
# Token 0, SV 2: alous ikit rather ilton Orb ató мов tvar
# Token 0, SV 3: 体 purs anto én poi HAV Bon ราช
# Token 0, SV 4: ulong rophe clr fax woo estroy DESCRIPTION uncture
# Token 0, SV 5: ams tro amba angers rams tro iba TAM
# Token 0, SV 6: ian imperson poll EDA loor ajan EMU autoimmune
# Token 0, SV 7: imus tran mute 統 ifice jí phen quan
# Layer 13
# Computing SVD for token position 0
# Token 0, SV 0: Frid wrath Encounter Giang прич victims 儀 erman
# Token 0, SV 1: key uman key umas Edison icles qt šem
# Token 0, SV 2: เค Bucket inya Frequency OrCreate frequency Pul Male
# Token 0, SV 3: part uring knocked zel lane activity argas mant
# Token 0, SV 4: slim ppy grading ycin zsche thick dense zag
# Token 0, SV 5: called ibu Called tote called none Cab NONE
# Token 0, SV 6: imoto urement straight зи inka upt supplier LTR
# Token 0, SV 7: least oldest ester Least Directive least Option confirmed
# Layer 16
# Computing SVD for token position 0
# Token 0, SV 0: highway Highway freeway road highways roads traffic Hwy
# Token 0, SV 1: most greatest biggest 最 hardest largest toughest 가장
# Token 0, SV 2: equivalent sole embodiment epit third orest culmination backbone
# Token 0, SV 3: transferring 抬 Plantae Lewis ballistic slammed belts divisions
# Token 0, SV 4: line pathway pathways line path Path paths plane
# Token 0, SV 5: complex 崎 railroad ferry Vert union vert towers
# Token 0, SV 6: called Called called ادة leton olan fund Called
# Token 0, SV 7: exposures erture depths voz gist 提示 Compat aviest
# Layer 19
# Computing SVD for token position 0
# Token 0, SV 0: highway highways Highway freeway Interstate Hwy interstate Route
# Token 0, SV 1: Oakland Palo Bay Stanford Berkeley SF Marin Daly
# Token 0, SV 2: gates bridges bridge gate barriers passes Bridge barrier
# Token 0, SV 3: Ventura UCLA Vent UCS uen vent unction intr
# Token 0, SV 4: result result Result Result (result resultado résult consequence
# Token 0, SV 5: source sources source Source Sources Source -source sources
# Token 0, SV 6: California California Californ Los california Calif Los ifornia
# Token 0, SV 7: Airport airport airports Airport Heath airport Mal Stap
# Layer 22
# Computing SVD for token position 0
# Token 0, SV 0: pont br Pont br BR BR Br Pont
# Token 0, SV 1: Cann bad ultz permalink aste Adjustable anghai undle
# Token 0, SV 2: electronics Sne K rice Alexander Til Bag Gam
# Token 0, SV 3: é units Units Caribbean witch tropical бу Intr
# Token 0, SV 4: deck patio Deck balcony dock decks terrace porch
# Token 0, SV 5: winding zig twisting circuit twists twist me wind
# Token 0, SV 6: Pacific NY Gl NY atur farm Bergen chia
# Token 0, SV 7: Crossing crossing crossed crossings intersection intersections intersection cross
# Layer 24
# Computing SVD for token position 0
# Token 0, SV 0: light light interchange clo ramp exit Light exchange
# Token 0, SV 1: Sal Holl wre Watson mole amon sal oru
# Token 0, SV 2: Bench mime mic genu sung Hess statutory ỉnh
# Token 0, SV 3: pl sob Kurt j Gr counter Tos \t
# Token 0, SV 4: legt oron Und ทย pun Tail HT AIT
# Token 0, SV 5: Downtown central centrally Central centralized Rafael downtown irates
# Token 0, SV 6: ess aint western Rev หม rev esp eastern
# Token 0, SV 7: azzi col pret fres ti Gu zi planted
# Layer 25
# Computing SVD for token position 0
# Token 0, SV 0: arga oretical propag िषय coping lives zo tha
# Token 0, SV 1: Cycl cul med Williams MED cob Sloan inf
# Token 0, SV 2: bike cycl biking Cs ciclo Trails -INF anela
# Token 0, SV 3: 45 Forty 49 46 48 47 Sevent Nin
# Token 0, SV 4: the 健 占 Gap the tee � Reach
# Token 0, SV 5: the spider span Span SP spans اجه Specs
# Token 0, SV 6: 苗 tok 米 trecht opc ros مان obi
# Token 0, SV 7: Sac gasoline indica racer gluc fighters Shak ē
# Layer 26
# Computing SVD for token position 0
# Token 0, SV 0: Has Had All Had Shall Has Aren Is
# Token 0, SV 1: ductive ses ffee thermal ilt ially pository ients
# Token 0, SV 2: B FX g gether oretical g teen б
# Token 0, SV 3: B B .B _b _B -B b .b
# Token 0, SV 4: N N C .N nip This C cerv
# Token 0, SV 5: shade owl år shed roof tpl gaard äch
# Token 0, SV 6: izen 役 olly SUCCESS exerc tomorrow Draft Prize
# Token 0, SV 7: erb デル elry Yard aqu axe adro ria
# Layer 27
# Computing SVD for token position 0
# Token 0, SV 0: last only Last new and trans on key
# Token 0, SV 1: '' `` '' '] ``( ,'' '', „
# Token 0, SV 2: “ ’s ‘ ’re ’m ’ll ’ ’ve
# Token 0, SV 3: O OF Ol Ok (O _O Od Or
# Token 0, SV 4: o о o Earl -o $o ower Ear
# Token 0, SV 5: … … ... And Crack Arrest […] •
# Token 0, SV 6: p " and they ent Pav ' des
# Token 0, SV 7: … …” – […] …) ,… […] …
# Mode: singular_vectors_layers_layerwise
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 20736 (\N{CJK UNIFIED IDEOGRAPH-5100}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 2359 (\N{DEVANAGARI LETTER SSA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 20736 (\N{CJK UNIFIED IDEOGRAPH-5100}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 2359 (\N{DEVANAGARI LETTER SSA}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# Layer 1
# Computing SVD for token position 0
# Token 0, SV 0: , . os i ar l a iro
# Token 0, SV 1: ,   . ( - and in
# Token 0, SV 2: prosec rosso uni ​​ 展 prote endo cone
# Token 0, SV 3: active いる blur active res ataka abras finish
# Token 0, SV 4: uko Beispiel ske traction odel uge idding Ske
# Token 0, SV 5: stru tiler INGS autoload ardu aug hana tera
# Token 0, SV 6: . -   a 1 ( ...
# Token 0, SV 7: GIN организа gon mpl jom BOR agreg �
# Layer 4
# Computing SVD for token position 0
# Token 0, SV 0: unge stands correction avigation accompanying operation 立 pps
# Token 0, SV 1: ingo entin ilo Alto allotted tant instein terra
# Token 0, SV 2: Site earrings Celebr celebration κλη studs .ordinal Celebration
# Token 0, SV 3: Belt aria Hold तक Terry _most Terr vised
# Token 0, SV 4: culmination scientific crets Scientific Sunday Laugh � Saturday
# Token 0, SV 5: off Gam orman olor Kingdom lowering RI ớ
# Token 0, SV 6: isolation deserted Floor developer desert isol Tcp 味
# Token 0, SV 7: แต pur inward rium iform Intr ibur गल
# Layer 7
# Computing SVD for token position 0
# Token 0, SV 0: owi Eh óm cor raig efe enu Mid
# Token 0, SV 1: eler Lean amp alaria TY lemn Ty presidential
# Token 0, SV 2: Grand most most Square hran yar square Grand
# Token 0, SV 3: � Extra dram حر orry grate offer Hero
# Token 0, SV 4: insulated loat inary Made Jasper adult collapses igure
# Token 0, SV 5: artz eger 居 fo LSD Empire Mour asso
# Token 0, SV 6: inspect 취 stru handled Buckingham Rew surrendered arrant
# Token 0, SV 7: itan spre Rag onym � quo Sherlock Maid
# Layer 10
# Computing SVD for token position 0
# Token 0, SV 0: else fright abort though 体 cond 驚 式
# Token 0, SV 1: pale major oko ofi mat mature spor 回
# Token 0, SV 2: assurance Assurance .eth outside esp nes omain Revision
# Token 0, SV 3: orda Twe ockey cy lä itate buz уска
# Token 0, SV 4: signed dedicated signed 典 wear etros Contractors cork
# Token 0, SV 5: 町 itage isay uch .pol Dawson Wonder lder
# Token 0, SV 6: yang gre ereal ivering Turing avin icer gin
# Token 0, SV 7: rone Unters gent tie stabilized principal licate Princip
# Layer 13
# Computing SVD for token position 0
# Token 0, SV 0: reflection Giang Reflect uro prot Reflect reflecting awy
# Token 0, SV 1: Knot uman inevitable trick testament quickest tool ugh
# Token 0, SV 2: Prop distant oad abella 番 necessary oise prop
# Token 0, SV 3: currently ffen ald _since currently Via udur obi
# Token 0, SV 4: few Few acking Cz eria cry OfWork arez
# Token 0, SV 5: access enough JOR difficulty flexibility inkel stability gift
# Token 0, SV 6: fond ihan rede ос /operators ATER coli olini
# Token 0, SV 7: lya erna dose dash last Plains separate crunchy
# Layer 16
# Computing SVD for token position 0
# Token 0, SV 0: Highway slammed highway StatefulWidget Hwy aup corrid ữa
# Token 0, SV 1: exit road Highway highway Fre freeway Road traffic
# Token 0, SV 2: ending plete rendered eing apt richt olum contrast
# Token 0, SV 3: reads ASAP gol izer Believe differently alker Lima
# Token 0, SV 4: greatest 最 biggest most 가장 naj best सबस
# Token 0, SV 5: ful epit erral third king agra seasons deaux
# Token 0, SV 6: 最 greatest worst most toughest सबस Worst 最
# Token 0, SV 7: weather laz Soy quil occasion idd incident 起
# Layer 19
# Computing SVD for token position 0
# Token 0, SV 0: highways highway Highway Interstate freeway Hwy interstate Route
# Token 0, SV 1: Oakland Sacramento Berkeley Palo Bay Silicon Marin Stanford
# Token 0, SV 2: bridges gates bridge barriers passes barrier gate junction
# Token 0, SV 3: Californ California Pacific Pacific California lég unction Vand
# Token 0, SV 4: California California Los Los Californ UCLA california San
# Token 0, SV 5: result result Result Result (result results resultado résult
# Token 0, SV 6: punk vent Ventura Cond Barg vent Thousand intr
# Token 0, SV 7: airport Airport airports Airport airport road Road 机场
# Layer 22
# Computing SVD for token position 0
# Token 0, SV 0: pont Pont br br BR Br Pont -br
# Token 0, SV 1: Mile Appro Travis Dash gene trails bad Trials
# Token 0, SV 2: stra egral inde wrap terr Brazilian  dec
# Token 0, SV 3: units Units é eg 抽 osos лаш ivery
# Token 0, SV 4: deck Deck terr patio decks dock porch terrace
# Token 0, SV 5: winding wind twisting twists winds twist me wound
# Token 0, SV 6: crossing Crossing Shall overs crossover Riverside crossings lights
# Token 0, SV 7: cross crossed crossing cross .cross Crossing Cross crosses
# Layer 24
# Computing SVD for token position 0
# Token 0, SV 0: light light Light interchange Light ramp LIGHT inter
# Token 0, SV 1: Sal Watson oru Holl abay wre sal Wat
# Token 0, SV 2: Imper 承 Stat genu Mik enth Bench entric
# Token 0, SV 3: San San san san SAN SAN _san sanction
# Token 0, SV 4: phía western elter caches southern southwestern Webster legt
# Token 0, SV 5: pok Deutsch Briggs asmine Pratt ghost Haupt leopard
# Token 0, SV 6: Cur cur grade Cur Prem ‏ /UIKit Wide
# Token 0, SV 7: San San san SAN SAN san -san SF
# Layer 25
# Computing SVD for token position 0
# Token 0, SV 0: span span Span spans Span Spanish (span _span
# Token 0, SV 1: drivers cycle Cycle Cycle ciclo driver Drivers cycle
# Token 0, SV 2: most altern ific many better coast relative denomin
# Token 0, SV 3: span Span Span span -span spans _span spanning
# Token 0, SV 4: mud mut مي vari incoming salt flu bib
# Token 0, SV 5: all comp al se the tw first one
# Token 0, SV 6: gas Gas Gas gas GAS _gas gases -g
# Token 0, SV 7: -b _b b .b -B B .B _B
# Layer 26
# Computing SVD for token position 0
# Token 0, SV 0: All No As Is So Has All Was
# Token 0, SV 1: WORD XT wrapper Bedford humming SET Gat Container
# Token 0, SV 2: same same final very Same state Same own
# Token 0, SV 3: g amar Nass ilton ynn anner ihan ona
# Token 0, SV 4: ses uras ductive duct comm eration thermal eor
# Token 0, SV 5: the this some a those its their any
# Token 0, SV 6: B B -b -B "B _b .B b
# Token 0, SV 7: .transfer well trans Well well Maggie str Shipping
# Layer 27
# Computing SVD for token position 0
# Token 0, SV 0: last Last only new bridge Bridge key final
# Token 0, SV 1: la Organization fic dozen youngest Organization prism than
# Token 0, SV 2: S  D N H P purpose G
# Token 0, SV 3: the Trans trans Ass  an F their
# Token 0, SV 4: the an a their his its your The
# Token 0, SV 5: re F RE let only M last D
# Token 0, SV 6: the a the The aken his an its
# Token 0, SV 7: Internal IQ anship COVERY .Internal inars cil Social
# Mode: singular_vectors_layers_layerwise
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 31435 (\N{CJK UNIFIED IDEOGRAPH-7ACB}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 20307 (\N{CJK UNIFIED IDEOGRAPH-4F53}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 39514 (\N{CJK UNIFIED IDEOGRAPH-9A5A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 24335 (\N{CJK UNIFIED IDEOGRAPH-5F0F}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 31435 (\N{CJK UNIFIED IDEOGRAPH-7ACB}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 20307 (\N{CJK UNIFIED IDEOGRAPH-4F53}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 39514 (\N{CJK UNIFIED IDEOGRAPH-9A5A}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 24335 (\N{CJK UNIFIED IDEOGRAPH-5F0F}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# Layer 1
# Computing SVD for token position 0
# Token 0, SV 0: ,  ( and . in  -
# Token 0, SV 1: , .  : -  ( /
# Token 0, SV 2:  1 2 -  3 B _
# Token 0, SV 3: 1 umn � 2 gebra Pare An ah
# Token 0, SV 4: ?") ?): .").  PS !". ?)  tom ...
# Token 0, SV 5: - z  1 impunity in 2 v
# Token 0, SV 6: olg � overst � %</ competit Corp -U
# Token 0, SV 7: . , to in of ( and .
# Layer 4
# Computing SVD for token position 0
# Token 0, SV 0: mess umb Bottom igan ER 法人 emic rout
# Token 0, SV 1: Balt icont mailto abundant @qq gains arious rr
# Token 0, SV 2: 式 infl demean real lish steady fashion receptive
# Token 0, SV 3: Bris cock etest worm verse ego gamble Cock
# Token 0, SV 4: ideon Sunny arden whether aurus addock ilded when
# Token 0, SV 5: Segment portable movable THAN than ث odb Portable
# Token 0, SV 6: strap Pretty đối global pretty pretty astr cases
# Token 0, SV 7: quen anged .doc etimes itud organisers opic vari
# Layer 7
# Computing SVD for token position 0
# Token 0, SV 0: dunk lug ści боя perk intim fond 음
# Token 0, SV 1: atoon UCT ادل Script istor fir navig peptide
# Token 0, SV 2: Pres labels Ler ug label code oken pres
# Token 0, SV 3: yer Ced bable ett sville staples pec onian
# Token 0, SV 4: Wayback coc del sk ylene rol ench scientists
# Token 0, SV 5: mission hire Mission edy kins ahoma Mission moist
# Token 0, SV 6: awks gatsby redential cra av Cert OTION SEO
# Token 0, SV 7: Crosby logy asser SM visually charcoal vre oron
# Layer 10
# Computing SVD for token position 0
# Token 0, SV 0: dams Sets 概 /router throttle Workspace Obr ugs
# Token 0, SV 1: ivial hub ihan hi ivia .Companion ugin hubs
# Token 0, SV 2: Cheap ucer ivel itle hift mee igger cheap
# Token 0, SV 3: oin Marsh éal Desk Marsh еві Desk Rash
# Token 0, SV 4: PATCH patch eza 的情 Either Moose oose мен
# Token 0, SV 5: urb cheme cathedral Sole ame Persist Tuy �
# Token 0, SV 6: ame trand Craw iode current AME immel aupt
# Token 0, SV 7: Bent inv ickers uvian cir ratt batt Tanner
# Layer 13
# Computing SVD for token position 0
# Token 0, SV 0: 節 мот barg case denn hele else mot
# Token 0, SV 1: PIL plane duo onta okay .za paralle tum
# Token 0, SV 2: urve rix holm survivor suspended benh Warm neutral
# Token 0, SV 3: perpet transmissions ingu backwards transmission Mim eyes floats
# Token 0, SV 4: repairing iment surely reira hrad rag rag αι
# Token 0, SV 5: Broadcast tren broadcasters Broadcast さい errat broadcast .broadcast
# Token 0, SV 6: -symbol Symbol ikh public quette households 석 therefore
# Token 0, SV 7: possibly probable likely sounds hi Gap possibly .Format
# Layer 16
# Computing SVD for token position 0
# Token 0, SV 0: 節 节 ient uge rze irk 经 undert
# Token 0, SV 1: allot stream streams Streams erez eldon spot ongan
# Token 0, SV 2: city town ount place anch camps นว cities
# Token 0, SV 3: apart dom read board riott � premises frame
# Token 0, SV 4: Magazine messenger selected newspaper Gazette ář pieces magazine
# Token 0, SV 5: wives Highland ylv hei wife woman Lakes Gulf
# Token 0, SV 6: captivity eday latitude .vm helm Latitude womens crew
# Token 0, SV 7: Seattle Tacoma Seattle Surrey Ukraine Seahawks Karnataka Ecuador
# Layer 19
# Computing SVD for token position 0
# Token 0, SV 0: ,and %, (), %, {}, _, [], !,
# Token 0, SV 1: , ?, **, _, (), ., , ",
# Token 0, SV 2: notion fact question idea ability arc phrase principle
# Token 0, SV 3: problem dilemma challenge problema problème problem issue trouble
# Token 0, SV 4: fact reason ovy fact reasons 因 irror Fact
# Token 0, SV 5: idea fact option oto concept Concept illusion Idea
# Token 0, SV 6: rack racks omb Rut phere batim agna üst
# Token 0, SV 7: fact answer Vendor ér vendor ousse fact hướng
# Layer 22
# Computing SVD for token position 0
# Token 0, SV 0: German German Germany Germans Tampa german Germany Tamil
# Token 0, SV 1: Italian Italian Italy Italy Italians italian Italia italiano
# Token 0, SV 2: Italian Montana Italian Italy Wisconsin italian Milan Luigi
# Token 0, SV 3: Belgian Newport Alban Albania Belg Belgium Welsh Flem
# Token 0, SV 4: Dutch Holland Netherlands Amsterdam Rotterdam holland Belgian .nl
# Token 0, SV 5: Seattle Seattle Alger WA Scandinavian Norway Norwegian Tehran
# Token 0, SV 6: Louisiana Baton Caj Orleans LSU swamp Hait Quebec
# Token 0, SV 7: Leicester Cincinnati Danish Bengals Dane Denmark England Bang
# Layer 24
# Computing SVD for token position 0
# Token 0, SV 0: 遣 ozo BS Lazy breastfeeding osta gil lub
# Token 0, SV 1: ship ship ships Skip Sy exemption leukemia empt
# Token 0, SV 2: sn Dee Sn Sn (sn -sn Dé Dé
# Token 0, SV 3: Serg dean deb dealers pharm Decor island Dean
# Token 0, SV 4: Sa ship theme ships themes Sa Themes Ship
# Token 0, SV 5: Se se Se SE se -Se /se (se
# Token 0, SV 6: Se Se neighbourhood -Se se Sev seb SE
# Token 0, SV 7: city City City city themes threatened cities Threat
# Layer 25
# Computing SVD for token position 0
# Token 0, SV 0: the -the the on _the ,the ethe .the
# Token 0, SV 1: on auf On _on On .on -on на
# Token 0, SV 2: in on 在 trong 在 ใน في trên
# Token 0, SV 3: yny ấm ่างก sûr arie irty ypse EPROM
# Token 0, SV 4: să at aby abych incer 去 rides isd
# Token 0, SV 5: from from FROM từ _from จาก From -from
# Token 0, SV 6: from From From from dari FROM .from _from
# Token 0, SV 7: from within FROM from inside From within among
# Layer 26
# Computing SVD for token position 0
# Token 0, SV 0: brig ate hazards Alam Alejandro vel okers margins
# Token 0, SV 1: Mac mac Mack Mac MAC macro /mac mac
# Token 0, SV 2: Mike Mike Lamb Gordon MI mic mike Mi
# Token 0, SV 3: MR MR Mr mr mr Mr _mr Ms
# Token 0, SV 4: MD PD MD md md NR PD Lam
# Token 0, SV 5: Harry TS Harry Thomas Ham Ham Han ts
# Token 0, SV 6: Bah Bah Brian Bac beta Beta Beth bah
# Token 0, SV 7: Thomas Mac Mac Henry Thomas Stephen Steven Henry
# Layer 27
# Computing SVD for token position 0
# Token 0, SV 0: “ ‘ ’s (“ “[ ’m ’re ’t
# Token 0, SV 1: `` '' „ ‐ ``( '' '] ,''
# Token 0, SV 2: – – … … – … […] –and
# Token 0, SV 3: ... ... ... ... ,... .... .... –
# Token 0, SV 4: ' - ﻿ -' ﻿ (' " —"
# Token 0, SV 5: ... ... ... … ..." … ...) ...,
# Token 0, SV 6: ‘ ' ‘ (' '- (' -' ​​
# Token 0, SV 7: — — — — —" — —— .—
# Mode: singular_vectors_layers_layerwise
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 27861 (\N{CJK UNIFIED IDEOGRAPH-6CD5}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 27010 (\N{CJK UNIFIED IDEOGRAPH-6982}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 31680 (\N{CJK UNIFIED IDEOGRAPH-7BC0}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 33410 (\N{CJK UNIFIED IDEOGRAPH-8282}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 32463 (\N{CJK UNIFIED IDEOGRAPH-7ECF}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1050: UserWarning: Glyph 36963 (\N{CJK UNIFIED IDEOGRAPH-9063}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 27861 (\N{CJK UNIFIED IDEOGRAPH-6CD5}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 27010 (\N{CJK UNIFIED IDEOGRAPH-6982}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 31680 (\N{CJK UNIFIED IDEOGRAPH-7BC0}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 33410 (\N{CJK UNIFIED IDEOGRAPH-8282}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 32463 (\N{CJK UNIFIED IDEOGRAPH-7ECF}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# /content/llms-are-llms/src/JacobianAnalyzer.py:1054: UserWarning: Glyph 36963 (\N{CJK UNIFIED IDEOGRAPH-9063}) missing from font(s) DejaVu Sans.
#   plt.savefig(f'{filename_png}.png', bbox_inches='tight')
# CPU times: user 56min 20s, sys: 1min 7s, total: 57min 27s
# Wall time: 25min 52s
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 21482 (\N{CJK UNIFIED IDEOGRAPH-53EA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 26696 (\N{CJK UNIFIED IDEOGRAPH-6848}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27969 (\N{CJK UNIFIED IDEOGRAPH-6D41}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20855 (\N{CJK UNIFIED IDEOGRAPH-5177}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3619 (\N{THAI CHARACTER RO RUA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 38453 (\N{CJK UNIFIED IDEOGRAPH-9635}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2339 (\N{DEVANAGARI LETTER NNA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3629 (\N{THAI CHARACTER O ANG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 22238 (\N{CJK UNIFIED IDEOGRAPH-56DE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31532 (\N{CJK UNIFIED IDEOGRAPH-7B2C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20736 (\N{CJK UNIFIED IDEOGRAPH-5100}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2359 (\N{DEVANAGARI LETTER SSA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 2351 (\N{DEVANAGARI LETTER YA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31435 (\N{CJK UNIFIED IDEOGRAPH-7ACB}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20307 (\N{CJK UNIFIED IDEOGRAPH-4F53}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 39514 (\N{CJK UNIFIED IDEOGRAPH-9A5A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 24335 (\N{CJK UNIFIED IDEOGRAPH-5F0F}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27861 (\N{CJK UNIFIED IDEOGRAPH-6CD5}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20154 (\N{CJK UNIFIED IDEOGRAPH-4EBA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51020 (\N{HANGUL SYLLABLE EUM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27010 (\N{CJK UNIFIED IDEOGRAPH-6982}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 31680 (\N{CJK UNIFIED IDEOGRAPH-7BC0}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 33410 (\N{CJK UNIFIED IDEOGRAPH-8282}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 32463 (\N{CJK UNIFIED IDEOGRAPH-7ECF}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 36963 (\N{CJK UNIFIED IDEOGRAPH-9063}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
analyzer.plot_dimensionality(layerwise=True,filename_png="fig6_dimensionality_layerwise")

# %%
from IPython.display import Image, display
pngs = !ls -l *.png
[display(Image(im[im.find('fig'):])) for im in pngs[:]]
